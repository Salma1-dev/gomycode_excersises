# %%
import pandas as pd

credit_df = pd.read_csv (r'C:\Users\pc\Documents\CC GENERAL.csv', sep = ',')
print (credit_df)
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
column_names = label_df.columns
for column in column_names:
    print(column + ' - ' + str(label_df[column].isnull().sum()))
# Out:
# CUST_ID - 0
# BALANCE - 0
# BALANCE_FREQUENCY - 0
# PURCHASES - 0
# ONEOFF_PURCHASES - 0
# INSTALLMENTS_PURCHASES - 0
# CASH_ADVANCE - 0
# PURCHASES_FREQUENCY - 0
# ONEOFF_PURCHASES_FREQUENCY - 0
# PURCHASES_INSTALLMENTS_FREQUENCY - 0
# CASH_ADVANCE_FREQUENCY - 0
# CASH_ADVANCE_TRX - 0
# PURCHASES_TRX - 0
# CREDIT_LIMIT - 0
# PAYMENTS - 0
# MINIMUM_PAYMENTS - 0
# PRC_FULL_PAYMENT - 0
# TENURE - 0

# %%
credit_df["CREDIT_LIMIT"] = credit_df["CREDIT_LIMIT"].fillna(label_df["CREDIT_LIMIT"].mean())

print(credit_df["CREDIT_LIMIT"].value_counts())
# Out:
# 3000.0     784
# 1500.0     722
# 1200.0     621
# 1000.0     614
# 2500.0     612
#           ...
# 10100.0      1
# 4950.0       1
# 4050.0       1
# 12300.0      1
# 17150.0      1
# Name: CREDIT_LIMIT, Length: 206, dtype: int64

# %%
credit_df["MINIMUM_PAYMENTS"] = credit_df["MINIMUM_PAYMENTS"].fillna(label_df["MINIMUM_PAYMENTS"].mean())

print(credit_df["MINIMUM_PAYMENTS"].value_counts())
# Out:
# 864.206542     313
# 299.351881       2
# 1666.085318      1
# 5583.630482      1
# 129.682608       1
#               ...
# 825.485459       1
# 1227.773229      1
# 127.210691       1
# 6422.472544      1
# 189.459157       1
# Name: MINIMUM_PAYMENTS, Length: 8637, dtype: int64

# %%
credit_df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
import pandas as pd

credit_df = credit_df.drop("CUST_ID", axis=1)

# %%
from sklearn.cluster import AgglomerativeClustering 
model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
clust_labels = model.fit_predict(credit_df)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (credit_df ["BALANCE"] , credit_df ["PAYMENTS"], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("BALANCE")
ax.set_ylabel("PAYMENTS")
plt.colorbar(scatter)

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(credit_df, method="complete"),10,  "level")

# %%
from sklearn.cluster import KMeans  
kmeans = KMeans(n_clusters=5, random_state=0)  
kmeans.fit(credit_df)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
credit_df["label"] = kmeans.labels_

# %%
plt.scatter(credit_df["BALANCE"][credit_df.label == 0],          
            credit_df["PAYMENTS"][credit_df.label == 0],s=80,c='magenta',label='Careful')
plt.scatter(credit_df["BALANCE"][credit_df.label == 1],
           credit_df["PAYMENTS"][credit_df.label == 1],s=80,c='yellow',label='Standard')
plt.scatter(credit_df["BALANCE"][credit_df.label == 2],
           credit_df["PAYMENTS"][credit_df.label == 2],s=80,c='green',label='Target')
plt.scatter(credit_df["BALANCE"][credit_df.label == 3], 
           credit_df["PAYMENTS"][credit_df.label == 3],s=80,c='cyan',label='Careless')
plt.scatter(credit_df["BALANCE"][credit_df.label == 4], 
           credit_df["PAYMENTS"][credit_df.label == 4],s=80,c='burlywood',label='Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red')
plt.title('Clusters of Customers')
plt.xlabel('BALANCE')
plt.ylabel('PAYMENTS')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
K = range(1,10)
distortions = []
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(credit_df)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
credit_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
kmeanModel = KMeans(n_clusters=3)
kmeanModel.fit(credit_df)
# Out:
# KMeans(n_clusters=3)

# %%
credit_df['k_means']=kmeanModel.predict(credit_df)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(credit_df["BALANCE"],credit_df["PURCHASES"], c=credit_df['k_means'], cmap=plt.cm.Set1)
ax.set_title('K_Means', fontsize=18)
# Out:
# Text(0.5, 1.0, 'K_Means')

# %% [markdown]
# Comparison
# The first clusters they were only blue but when we changed values the clusters had three different colours
